# %%
pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /opt/anaconda3/lib/python3.12/site-packages (2.0.34)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from sqlalchemy) (4.11.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in /opt/anaconda3/lib/python3.12/site-packages (0.5.0)
# Requirement already satisfied: prettytable in /opt/anaconda3/lib/python3.12/site-packages (from ipython-sql) (3.12.0)
# Requirement already satisfied: ipython in /opt/anaconda3/lib/python3.12/site-packages (from ipython-sql) (8.27.0)
# Requirement already satisfied: sqlalchemy>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from ipython-sql) (2.0.34)
# Requirement already satisfied: sqlparse in /opt/anaconda3/lib/python3.12/site-packages (from ipython-sql) (0.5.2)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.12/site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in /opt/anaconda3/lib/python3.12/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from sqlalchemy>=2.0->ipython-sql) (4.11.0)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.12/site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.12/site-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/lib/python3.12/site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.12/site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from ipython->ipython-sql) (2.15.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.12/site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.12/site-packages (from ipython->ipython-sql) (4.8.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.12/site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.12/site-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext sql
from sqlalchemy import create_engine
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %%
# %sql postgresql://postgres:@localhost:5432/absadatabase

# %% [markdown]
# ### LIABILITY FULLFILLED BY THE BANK
#
# 1. **ACB DEBIT REVERSAL** – Reversals debited from customer accounts.
# 2. **ACB DEBIT:EXTERNAL** – External ACB debit orders processed from customer accounts.
# 3. **ACB DEBIT:INTERNAL** – Internal ACB debit orders processed from customer accounts.
# 4. **ACB EXT DISP ONLNE** – External disbursements debited via online channels.
# 5. **ACB INT DISP BRNCH** – Internal disbursements debited at branches.
# 6. **ACB INT DISP ONLNE** – Internal disbursements debited via online channels.
# 7. **ACT PAYMENT FROM** – Payments debited from customer accounts.
# 8. **AIRTIME DBT ATMS** – Airtime purchases made at ATMs.
# 9. **AIRTIME DEBIT** – Airtime purchases debited from accounts.
# 10. **AIRTIME DEBIT COR** – Airtime debit corrections.
# 11. **ATM PAYMENT TO** – Payments debited via ATMs.
# 12. **ATM TRANSFER** – Transfers made via ATMs debited from accounts.
# 13. **ATM WITHDRAWAL** – Cash withdrawals from ATMs debited from accounts.
# 14. **BAD DEBT W/OFF** – Write-offs debited from customer accounts.
# 15. **CASHSEND ATM** – CashSend payments initiated via ATM debited from accounts.
# 16. **CASHSEND DIGITAL** – CashSend payments initiated digitally debited from accounts.
# 17. **CASHSEND IB** – CashSend payments initiated via internet banking debited from accounts.
# 18. **CASHSEND MB** – CashSend payments initiated via mobile banking debited from accounts.
# 19. **CHARGES** – Service charges debited from customer accounts.
# 20. **CHARGES - CLOSURE** – Account closure charges debited.
# 21. **CLOSE C/WITHDRAWAL** – Account closure withdrawals.
# 22. **DIGITAL PAYMENT DT** – Digital payments debited from customer accounts.
# 23. **DIGITAL TRANSF DT** – Digital transfers debited from customer accounts.
# 24. **DO EXT DISP BRANCH** – External disbursements processed at branches debited.
# 25. **DO EXT DISP ONLNE** – External disbursements processed online debited.
# 26. **DO INT DISP ONLNE** – Internal disbursements processed online debited.
# 27. **EXT STOP ORDER TO** – External standing orders debited from customer accounts.
# 28. **IBANK PAYMENT TO** – Payments made via internet banking debited.
# 29. **INET IMMEDIATE PMT** – Immediate payments via internet debited from accounts.
# 30. **INT DEBIT ORDER TO** – Internal debit orders debited from accounts.
# 31. **LOTTO PURCHASE** – Lottery purchases debited from customer accounts.
# 32. **MANAGEMENT FEE** – Management fees debited from accounts.
# 33. **MOBILE PAYMENT DT** – Payments made via mobile banking debited from accounts.
# 34. **MOBILE TRANSFER DT** – Mobile transfers debited from customer accounts.
# 35. **NAEDO DEBIT ORDER** – Non-Authenticated Early Debit Orders debited from accounts.
# 36. **NAEDO DO UNPD** – Unpaid NAEDO debit orders debited from accounts.
# 37. **NPF DEBIT** – Debit transactions under NPF from customer accounts.
# 38. **OD: INITIATION FEE** – Overdraft initiation fees debited from accounts.
# 39. **OD: LEDGER FEE** – Overdraft ledger fees debited from accounts.
# 40. **POS PURCHASE** – Point-of-sale purchases debited from accounts.
# 41. **PREPAID DEBIT** – Prepaid transactions debited from accounts.
# 42. **REWARDS FEE** – Rewards program fees debited from accounts.
# 43. **SCAN TRANSFER TO** – Transfers via scanning debited from accounts.
# 44. **STOP ORDER TO** – Standing orders debited from customer accounts.
# 45. **TRAVEL FOREX(PFC)** – Travel forex transactions debited from accounts.
# 46. **TRAVEL FOREX(TFC)** – Travel forex charges debited.
# 47. **UNPAID DEBIT** – Unpaid debits processed from accounts.
#
# ---
#
# ### **Key Insights**
# - **Withdrawals, payments, transfers, fees, and charges** are all categorized as outflows, reducing customer account balances.
# - **ABSA fullfiling liabilities**

# %%
# %%sql
# SELECT
# *
# FROM
#     transactiondata
# WHERE
#     transaction_description IN ('ACB DEBIT REVERSAL',
# 'ACB DEBIT:EXTERNAL',
# 'ACB DEBIT:INTERNAL',
# 'ACB EXT DISP ONLNE',
# 'ACB INT DISP BRNCH',
# 'ACB INT DISP ONLNE',
# 'ACT PAYMENT FROM',
# 'AIRTIME DBT ATMS',
# 'AIRTIME DEBIT',
# 'AIRTIME DEBIT COR',
# 'ATM PAYMENT TO',
# 'ATM TRANSFER',
# 'ATM WITHDRAWAL',
# 'BAD DEBT W/OFF',
# 'CASHSEND ATM',
# 'CASHSEND DIGITAL',
# 'CASHSEND IB',
# 'CASHSEND MB',
# 'CHARGES',
# 'CHARGES - CLOSURE',
# 'CLOSE C/WITHDRAWAL',
# 'DIGITAL PAYMENT DT',
# 'DIGITAL TRANSF DT',
# 'DO EXT DISP BRANCH',
# 'DO EXT DISP ONLNE',
# 'DO INT DISP ONLNE',
# 'EXT STOP ORDER TO',
# 'IBANK PAYMENT TO',
# 'INET IMMEDIATE PMT',
# 'INT DEBIT ORDER TO',
# 'LOTTO PURCHASE',
# 'MANAGEMENT FEE',
# 'MOBILE PAYMENT DT',
# 'MOBILE TRANSFER DT',
# 'NAEDO DEBIT ORDER',
# 'NAEDO DO UNPD',
# 'NPF DEBIT',
# 'OD: INITIATION FEE',
# 'OD: LEDGER FEE',
# 'POS PURCHASE',
# 'PREPAID DEBIT',
# 'REWARDS FEE',
# 'SCAN TRANSFER TO',
# 'TRAVEL FOREX(PFC)',
# 'TRAVEL FOREX(TFC)',
# 'UNPAID DEBIT') limit 10
# Out:
#  * postgresql://postgres:***@localhost:5432/absadatabase
# 10 rows affected.
# [(228115, 'DIGITAL PAYMENT DT', 'ID_92ef0efd71aae865ff3eb1ac270490fa34de3fdbea31a93154f405252898d82f23cfb902b1d86e1e9f8560b071c953489f68c7552228b8f4add4053321fd5f39', datetime.datetime(2022, 3, 25, 0, 0), 'e92177da406abc0e0a5bce83e853dbdb4e792af521a0ae42494e0bf27ed164839766592c3c2bf9a5940793e7c6adc16c244c564fb4ae809daa9a3e01cbe72cf2', 14124.49, -300.0, 18268, 'CHEQ', 'internet', 'd3ed72136b6ba82e4bebce7c489b9e13bcd0a8e735cf865ba88144adcd815d718cddefe13c3e028918847b47f0991fc3260f7a0704e794cb974421c343f925bd', 'cae3192b69a9a9d24a92324124e86c7cc1342e46b1a11db5ae42ef5953815c27544915c64c16e457aa54caf0f9dcaa1c30375de6a91d0fbd868d99498e7d7b17'),
#  (228116, 'POS PURCHASE', 'ID_92ef0efd71aae865ff3eb1ac270490fa34de3fdbea31a93154f405252898d82f23cfb902b1d86e1e9f8560b071c953489f68c7552228b8f4add4053321fd5f39', datetime.datetime(2022, 8, 11, 0, 0), 'e92177da406abc0e0a5bce83e853dbdb4e792af521a0ae42494e0bf27ed164839766592c3c2bf9a5940793e7c6adc16c244c564fb4ae809daa9a3e01cbe72cf2', 1661.9, -200.0, 20486, 'CHEQ', 'system', 'd3ed72136b6ba82e4bebce7c489b9e13bcd0a8e735cf865ba88144adcd815d718cddefe13c3e028918847b47f0991fc3260f7a0704e794cb974421c343f925bd